# %% [markdown]
# # Bank Marketing Campaign

# %% [markdown]
# # Group name: Data Science Enthusiasts
# # Team member's details:
#
# ### Member 1:
#
# Name : Amira Asta
#
# Email : amira.asta02@gmail.com
#
# Country : Tunisia
#
# College/Company : Afrikanda
#
# Specialization : Data Science
#
# ### Member 2:
#
# Name : Vatsal Vinesh Mandalia
#
# Email : vatsalvm10@outlook.com
#
# Country : Oman
#
# College/Company : Graduated
#
# Specialization : Data Science

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read the data files

# %%
bank_full = pd.read_csv(r'C:\Users\Amira\Documents\PERSONAL\Data_Glacier_online_internship\Final_Project\Data\bank\bank-full.csv', delimiter=';')
bank_full.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
bank_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
bank_additional_full = pd.read_csv(r'C:\Users\Amira\Documents\PERSONAL\Data_Glacier_online_internship\Final_Project\Data\bank-additional\bank-additional\bank-additional-full.csv', delimiter=';')
bank_additional_full.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
bank_additional_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %% [markdown]
# ### EDA
# #### Missing values

# %%
bank_full.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
bank_additional_full.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# #### Duplicated rows

# %%
duplicated_rows = bank_full[bank_full.duplicated()]
print('Total number of duplicated rows is', duplicated_rows.shape[0])
# Out:
# Total number of duplicated rows is 0

# %%
duplicated_rows = bank_additional_full[bank_additional_full.duplicated()]
print('Total number of duplicated rows is', duplicated_rows.shape[0])
# Out:
# Total number of duplicated rows is 12

# %%
# drop duplicated rows
bank_additional_full.drop_duplicates(inplace = True)

bank_additional_full.shape
# Out:
# (41176, 21)

# %% [markdown]
# #### Remove 'Duration' feature

# %%
bank_additional_full=bank_additional_full.drop(['duration'],axis=1)
print(bank_additional_full.shape)
bank_additional_full.head()
# Out:
# (41176, 20)
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no

# %% [markdown]
# #### Numerical attributes

# %%
bank_additional_full.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
bank_additional_full.describe()
# Out:
#                age      campaign         pdays      previous  emp.var.rate  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380      2.567879    962.464810      0.173013      0.081922
# std       10.42068      2.770318    186.937102      0.494964      1.570883
# min       17.00000      1.000000      0.000000      0.000000     -3.400000
# 25%       32.00000      1.000000    999.000000      0.000000     -1.800000
# 50%       38.00000      2.000000    999.000000      0.000000      1.100000
# 75%       47.00000      3.000000    999.000000      0.000000      1.400000
# max       98.00000     56.000000    999.000000      7.000000      1.400000
#
#        cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count    41176.000000   41176.000000  41176.000000  41176.000000
# mean        93.575720     -40.502863      3.621293   5167.034870
# std          0.578839       4.627860      1.734437     72.251364
# min         92.201000     -50.800000      0.634000   4963.600000
# 25%         93.075000     -42.700000      1.344000   5099.100000
# 50%         93.749000     -41.800000      4.857000   5191.000000
# 75%         93.994000     -36.400000      4.961000   5228.100000
# max         94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# #### Let's explore the histograms of each numerical attribute

# %%
bank_additional_full.hist(figsize=(12,12))
# save the figure
#plt.savefig('plots/numerical_histogram.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Density plots of each numerical attribute

# %%
bank_additional_full.plot(kind='density', subplots=True, sharex=False, figsize=(9,10))
# save the figure
#plt.savefig('plots/numerical_density.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Box plot of each numerical attribute

# %%
bank_additional_full.plot(kind='box', subplots=True, sharex=False, sharey=False, figsize=(14,10))
# save the figure
# plt.savefig('plots/boxplots.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# Outliers: Outliers are defined as 1.5 x Q3 value (75th percentile).
#
# From the above table, it can be seen that only 'age' and 'campaign' have outliers as:
#
# $max('age') > 1.5Q3('age')$
#
# and
#
# $max('campaign') > 1.5Q3('campaign')$
#
# respectively.

# %%
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")
 
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_dist)
f, (ax_box, ax_dist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# assigning a graph to each ax

sns.boxplot(bank_additional_full['age'], palette='Blues', ax=ax_box)

sns.distplot(bank_additional_full['age'], kde=False, color='blue', ax=ax_dist)

# Remove x axis name for the boxplot
ax_box.set(xlabel='')

# setting title and labels
plt.title("Distribution of age attribute", fontsize=13, y=1.012)
plt.xlabel("Age", labelpad=15)
plt.ylabel("frequency", labelpad=15)

# save the figure
#plt.savefig('plots/age.jpg', dpi=200, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
bank_additional_full.query('20 < age <= 60').shape[0]/bank_additional_full.shape[0]
# Out:
# 0.9745239945599379

# %% [markdown]
# 97.5% of the clients fall in age range of 20 - 60 years old.

# %%
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")
 
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_dist)
f, (ax_box, ax_dist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# assigning a graph to each ax
sns.boxplot(bank_additional_full['campaign'], palette='Oranges', ax=ax_box)

sns.distplot(bank_additional_full['campaign'], kde=False, color='orange', ax=ax_dist)

# Remove x axis name for the boxplot
ax_box.set(xlabel='')

# setting title and labels
plt.title("Distribution of nb of contacts performed during this campaign", fontsize=13, y=1.012)
plt.xlabel("nb of contacts", labelpad=15)
plt.ylabel("frequency", labelpad=15)

# save the figure
#plt.savefig('plots/campaign.jpg', dpi=200, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")
 
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_dist)
f, (ax_box, ax_dist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# assigning a graph to each ax
sns.boxplot(bank_additional_full['previous'], palette='BuPu', ax=ax_box)

sns.distplot(bank_additional_full['previous'], kde=False, color='red', ax=ax_dist)

# Remove x axis name for the boxplot
ax_box.set(xlabel='')

# setting title and labels
plt.title("Distribution of nb of contacts performed before this campaign", fontsize=13, y=1.012)
plt.xlabel("nb of contacts", labelpad=15)
plt.ylabel("frequency", labelpad=15)

# save the figure
#plt.savefig('plots/previous.jpg', dpi=200, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Skewness & Kurtosis

# %%
# skewness along the index axis
bank_additional_full.skew(axis = 0, skipna = True)
# Out:
# age               0.784560
# campaign          4.762044
# pdays            -4.921386
# previous          3.831396
# emp.var.rate     -0.724061
# cons.price.idx   -0.230853
# cons.conf.idx     0.302876
# euribor3m        -0.709194
# nr.employed      -1.044317
# dtype: float64

# %%
# Kurtosis along the index axis
bank_additional_full.kurt(axis=0)
# Out:
# age                0.791113
# campaign          36.971857
# pdays             22.221553
# previous          20.102164
# emp.var.rate      -1.062698
# cons.price.idx    -0.829851
# cons.conf.idx     -0.359097
# euribor3m         -1.406791
# nr.employed       -0.003540
# dtype: float64

# %% [markdown]
# #### Categorical attributes

# %% [markdown]
# #### Job

# %%
plt.figure(figsize=(15,4))
sns.barplot(bank_additional_full['job'].value_counts().index, bank_additional_full['job'].value_counts().values)
plt.title('Distribution of Job attribute by category', fontsize=13, y=1.012)
# save the figure
# plt.savefig('plots/job.jpg', dpi=200, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#job and deposit
job_df = pd.DataFrame()
job_df['yes'] = bank_additional_full[bank_additional_full['y'] == 'yes']['job'].value_counts()
job_df['no'] = bank_additional_full[bank_additional_full['y'] == 'no']['job'].value_counts()
job_df.plot.bar(figsize=(15,4))
plt.title('Job and deposit distribuation', fontsize=13, y=1.012)

# save the figure
# plt.savefig('plots/job_vs_deposit.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Education

# %%
plt.figure(figsize=(15,4))
sns.barplot(bank_additional_full['education'].value_counts().index, bank_additional_full['education'].value_counts().values)
plt.title('Distribution of education attribute by category', fontsize=13, y=1.012)

# save the figure
#plt.savefig('plots/education.jpg', dpi=200, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#education and deposit
education_df = pd.DataFrame()
education_df['yes'] = bank_additional_full[bank_additional_full['y'] == 'yes']['education'].value_counts()
education_df['no'] = bank_additional_full[bank_additional_full['y'] == 'no']['education'].value_counts()
education_df.plot.bar(figsize=(15,4))
plt.title('education level and deposit distribuation', fontsize=13, y=1.012)

# save the figure
#plt.savefig('plots/education_vs_deposit.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Comment 1
# 1- Administrative staff and technical specialists opened the deposit most of all. In relative terms, a high proportion of pensioners and students might be mentioned as well.
#
# 2- Majority of the clients are employed in admin, blue-collar, technician and services job types.

# %% [markdown]
# #### marital

# %%
plt.figure(figsize=(15,4))
sns.barplot(bank_additional_full['marital'].value_counts().index, bank_additional_full['marital'].value_counts().values)
plt.title('Distribution of marital attribute by category', fontsize=13, y=1.012)

# save the figure
# plt.savefig('plots/marital.jpg', dpi=200, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#marital status and deposit
marital_df = pd.DataFrame()
marital_df['yes'] = bank_additional_full[bank_additional_full['y'] == 'yes']['marital'].value_counts()
marital_df['no'] = bank_additional_full[bank_additional_full['y'] == 'no']['marital'].value_counts()
marital_df.plot.bar(figsize=(15,4))
plt.title('marital status and deposit distribuation', fontsize=13, y=1.012)

# save the figure
# plt.savefig('plots/marital_vs_deposit.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Comment 2:
# 2- Although in absolute terms married consumers more often agreed to the service, in relative terms the single was responded better.

# %% [markdown]
# #### default

# %%
plt.figure(figsize=(15,4))
sns.barplot(bank_additional_full['default'].value_counts().index, bank_additional_full['default'].value_counts().values)
plt.title('Distribution of default attribute by category', fontsize=13, y=1.012)

# save the figure
# plt.savefig('plots/default.jpg', dpi=200, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#default and deposit
default_df = pd.DataFrame()
default_df['yes'] = bank_additional_full[bank_additional_full['y'] == 'yes']['default'].value_counts()
default_df['no'] = bank_additional_full[bank_additional_full['y'] == 'no']['default'].value_counts()
default_df.plot.bar(figsize=(15,4))
plt.title('default and deposit distribuation', fontsize=13, y=1.012)

# save the figure
# plt.savefig('plots/default_vs_deposit.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Loan

# %%
plt.figure(figsize=(15,4))
sns.barplot(bank_additional_full['loan'].value_counts().index, bank_additional_full['loan'].value_counts().values)
plt.title('Distribution of loan attribute by category', fontsize=13, y=1.012)

# save the figure
# plt.savefig('plots/loan.jpg', dpi=200, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#default and deposit
loan_df = pd.DataFrame()
loan_df['yes'] = bank_additional_full[bank_additional_full['y'] == 'yes']['loan'].value_counts()
loan_df['no'] = bank_additional_full[bank_additional_full['y'] == 'no']['loan'].value_counts()
loan_df.plot.bar(figsize=(15,4))
plt.title('loan and deposit distribuation', fontsize=13, y=1.012)

# save the figure
# plt.savefig('plots/loan_vs_deposit.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Comment 3:
# 3- The difference is evident between consumers who already use the services of banks and received a loan.

# %% [markdown]
# #### contact

# %%
plt.figure(figsize=(15,4))
sns.barplot(bank_additional_full['contact'].value_counts().index, bank_additional_full['contact'].value_counts().values)
plt.title('Distribution of contact attribute by category', fontsize=13, y=1.012)

# save the figure
# plt.savefig('plots/contact.jpg', dpi=200, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#default and deposit
contact_df = pd.DataFrame()
contact_df['yes'] = bank_additional_full[bank_additional_full['y'] == 'yes']['contact'].value_counts()
contact_df['no'] = bank_additional_full[bank_additional_full['y'] == 'no']['contact'].value_counts()
contact_df.plot.bar(figsize=(15,4))
plt.title('contact and deposit distribuation', fontsize=13, y=1.012)

# save the figure
# plt.savefig('plots/contact_vs_deposit.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Comment 4
# 4- Best communication channel is mobile phone.

# %% [markdown]
# #### Housing

# %%
plt.figure(figsize=(15,4))
sns.barplot(bank_additional_full['housing'].value_counts().index, bank_additional_full['housing'].value_counts().values)
plt.title('Distribution of housing attribute by category', fontsize=13, y=1.012)

# save the figure
#plt.savefig('plots/housing.jpg', dpi=200, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Amira\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#housing and deposit
housing_df = pd.DataFrame()
housing_df['yes'] = bank_additional_full[bank_additional_full['y'] == 'yes']['housing'].value_counts()
housing_df['no'] = bank_additional_full[bank_additional_full['y'] == 'no']['housing'].value_counts()
housing_df.plot.bar(figsize=(15,4))
plt.title('Housing and deposit distribuation', fontsize=13, y=1.012)

# save the figure
#plt.savefig('plots/housing_vs_deposit.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Comment 5:
# 5- Home ownership does not greatly affect marketing company performance.

# %% [markdown]
# ### Correlation between attributes:

# %%
# Convert target variable into numeric
bank_additional_full.y = bank_additional_full.y.map({'no':0, 'yes':1}).astype('uint8')

# %%
bank_additional_full['y']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41183    1
# 41184    0
# 41185    0
# 41186    1
# 41187    0
# Name: y, Length: 41176, dtype: uint8

# %%
bank_additional_full.corr()
# Out:
#                      age  campaign     pdays  previous  emp.var.rate  \
# age             1.000000  0.004622 -0.034381  0.024379     -0.000242
# campaign        0.004622  1.000000  0.052606 -0.079182      0.150786
# pdays          -0.034381  0.052606  1.000000 -0.587508      0.271063
# previous        0.024379 -0.079182 -0.587508  1.000000     -0.420587
# emp.var.rate   -0.000242  0.150786  0.271063 -0.420587      1.000000
# cons.price.idx  0.001009  0.127826  0.078920 -0.203197      0.775293
# cons.conf.idx   0.129075 -0.013657 -0.091374 -0.050929      0.196257
# euribor3m       0.010852  0.135169  0.296946 -0.454571      0.972244
# nr.employed    -0.017607  0.144129  0.372659 -0.501411      0.906949
# y               0.030381 -0.066361 -0.324948  0.230202     -0.298289
#
#                 cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# age                   0.001009       0.129075   0.010852    -0.017607
# campaign              0.127826      -0.013657   0.135169     0.144129
# pdays                 0.078920      -0.091374   0.296946     0.372659
# previous             -0.203197      -0.050929  -0.454571    -0.501411
# emp.var.rate          0.775293       0.196257   0.972244     0.906949
# cons.price.idx        1.000000       0.059170   0.688180     0.521945
# cons.conf.idx         0.059170       1.000000   0.277864     0.100679
# euribor3m             0.688180       0.277864   1.000000     0.945146
# nr.employed           0.521945       0.100679   0.945146     1.000000
# y                    -0.136134       0.054802  -0.307740    -0.354669
#
#                        y
# age             0.030381
# campaign       -0.066361
# pdays          -0.324948
# previous        0.230202
# emp.var.rate   -0.298289
# cons.price.idx -0.136134
# cons.conf.idx   0.054802
# euribor3m      -0.307740
# nr.employed    -0.354669
# y               1.000000

# %%
plt.figure(figsize=(20,10))
sns.heatmap(bank_additional_full.corr(),
            annot=True,
            vmin=-1,
            vmax=1,
            cmap="Blues")
# save the figure
#plt.savefig('plots/heatmap_1.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# Highly correlated features (employment rate, consumer confidence index, consumer price index) may describe clients state from different social-economic angles. Their variance might support model capacity for generalization.

# %%
# sns.pairplot(bank_additional_full)
# # plt.savefig('plots/pairplot.png', bbox_inches='tight')
# plt.show()

# %% [markdown]
# #### Percentage of Deposit
# Let's begin by checking what percentage of bank clients agree to open term deposit.

# %%
fig, ax = plt.subplots(figsize=(7,7))
plt.pie(bank_additional_full.y.value_counts(), 
        labels = bank_additional_full.y.value_counts().index, 
        autopct='%1.1f%%', 
        pctdistance=0.75, 
        colors = ['red', 'lime'],
        startangle = 90, 
        wedgeprops = {'width' : 0.45}, 
        textprops={'fontsize': 13})
plt.axis('square')
# set the legend 
chartBox = ax.get_position()
ax.set_position([chartBox.x0, chartBox.y0, chartBox.width*0.6, chartBox.height])
ax.legend(loc='upper center', bbox_to_anchor=(1.30, 0.8), shadow=True, ncol=1)

plt.title("Percentage of bank clients deposit agreement", fontsize=15, loc='left')
plt.tight_layout()

# save the figure
#plt.savefig('plots/pie_deposit.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# Out of the total calls that are made, 11.3 % of them are successful.

# %%
plt.figure(figsize=[14,4])
sns.countplot(x='month', hue='y',edgecolor="black", palette='Spectral', alpha=0.9, data=bank_additional_full)
sns.despine()
plt.title("Countplot of deposit per month")

# save the figure
plt.savefig('plots/deposit_per_month.jpg', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# It looks like the month of May is the most promising one.

# %% [markdown]
# ### Imputation for Categorical Data

# %%
pd.crosstab(bank_additional_full['job'], bank_additional_full['education'])
# Out:
# education      basic.4y  basic.6y  basic.9y  high.school  illiterate  \
# job
# admin.               77       151       499         3329           1
# blue-collar        2318      1425      3623          878           8
# entrepreneur        137        71       210          234           2
# housemaid           474        77        94          174           1
# management          100        85       166          298           0
# retired             597        75       145          276           3
# self-employed        93        25       220          118           3
# services            132       226       388         2680           0
# student              26        13        99          357           0
# technician           58        87       384          872           0
# unemployed          112        34       186          259           0
# unknown              52        22        31           37           0
#
# education      professional.course  university.degree  unknown
# job
# admin.                         363               5750      249
# blue-collar                    453                 94      454
# entrepreneur                   135                610       57
# housemaid                       59                139       42
# management                      89               2063      123
# retired                        241                284       97
# self-employed                  168                765       29
# services                       218                173      150
# student                         43                170      167
# technician                    3317               1809      212
# unemployed                     142                262       19
# unknown                         12                 45      131

# %% [markdown]
# #### Inferring education from jobs :
# From the cross-tabulation, it can be seen that people with management jobs usually have a university degree.
#
# Hence we replace 'education' with 'university.degree' wherever 'job' = management and 'education' = unknown,
#
# Similarly, 'job' = 'services' --> 'education' = 'high.school' and
#
# 'job' = 'housemaid' --> 'education' = 'basic.4y'.
#
# #### Inferring jobs from education :
# If 'education' = 'basic.4y' or 'basic.6y' or 'basic.9y' then the 'job' is usually 'blue-collar'.
#
# If 'education' = 'professional.course', then the 'job' = 'technician'.

# %%
bank_additional_full['job'][bank_additional_full['age']>60].value_counts()
# Out:
# retired          677
# housemaid         54
# admin.            47
# technician        34
# management        30
# unknown           21
# blue-collar       20
# self-employed      9
# entrepreneur       8
# unemployed         7
# services           2
# Name: job, dtype: int64

# %% [markdown]
# #### Inferring jobs from age:
# As we see, if 'age' > 60, then the 'job' is 'retired,' which makes sense.

# %%
bank_additional_full.loc[(bank_additional_full['education']=='unknown') & (bank_additional_full['job']=='management'), 'education'] = 'university.degree'
bank_additional_full.loc[(bank_additional_full['education']=='unknown') & (bank_additional_full['job']=='services'), 'education'] = 'high.school'
bank_additional_full.loc[(bank_additional_full['education']=='unknown') & (bank_additional_full['job']=='housemaid'), 'education'] = 'basic.4y'
bank_additional_full.loc[(bank_additional_full['job'] == 'unknown') & (bank_additional_full['education']=='basic.4y'), 'job'] = 'blue-collar'
bank_additional_full.loc[(bank_additional_full['job'] == 'unknown') & (bank_additional_full['education']=='basic.6y'), 'job'] = 'blue-collar'
bank_additional_full.loc[(bank_additional_full['job'] == 'unknown') & (bank_additional_full['education']=='basic.9y'), 'job'] = 'blue-collar'
bank_additional_full.loc[(bank_additional_full['job']=='unknown') & (bank_additional_full['education']=='professional.course'), 'job'] = 'technician'

# %%
bank_additional_full.loc[(bank_additional_full['age']>60) & (bank_additional_full['job']=='unknown'), 'job'] = 'retired'

# %%
pd.crosstab(bank_additional_full['job'], bank_additional_full['education'])
# Out:
# education      basic.4y  basic.6y  basic.9y  high.school  illiterate  \
# job
# admin.               77       151       499         3329           1
# blue-collar        2370      1447      3654          878           8
# entrepreneur        137        71       210          234           2
# housemaid           516        77        94          174           1
# management          100        85       166          298           0
# retired             597        75       145          276           3
# self-employed        93        25       220          118           3
# services            132       226       388         2830           0
# student              26        13        99          357           0
# technician           58        87       384          872           0
# unemployed          112        34       186          259           0
# unknown               0         0         0           37           0
#
# education      professional.course  university.degree  unknown
# job
# admin.                         363               5750      249
# blue-collar                    453                 94      454
# entrepreneur                   135                610       57
# housemaid                       59                139        0
# management                      89               2186        0
# retired                        241                285      111
# self-employed                  168                765       29
# services                       218                173        0
# student                         43                170      167
# technician                    3329               1809      212
# unemployed                     142                262       19
# unknown                          0                 44      117

# %% [markdown]
# As we can see, we are able to reduce the number of unknowns and enhance our data set.

# %% [markdown]
# ## Conclusions and recommendations.
#
#
# 1. Take into account the time of the company (May is the most effective)
#
# 2. Increase the time of contact with customers. It is possible to use other means of communication.
#
# 3. Focus on specific categories. Students and senior citizens respond better to this proposal.
#
# 4. It is imperative to form target groups based on sociological-economic categories. Age, income level (not always high), profession can accurately determine the marketing profile of a potential client.
#
# Given these factors, it is recommended to concentrate on those consumer groups that are potentially more promising.
